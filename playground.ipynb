# %% [markdown]
# __[The Human Phenotype Ontology](https://hpo.jax.org/app/)__
# <br> __[Medical News Today](https://www.medicalnewstoday.com/articles/321285#Detailed-information-about-food-sources)__
# <br> __[My Epilepsy Team](https://www.myepilepsyteam.com/resources/tuberous-sclerosis-complex-tsc-your-guide)__

# %% [markdown]
# <p>
#   <b>Cortical Dysplasia</b>
#   <br />
#   The presence of developmental dysplasia of the cerebral cortex.
#   <br />
#
# </p>
#
# __[Source 1](https://hpo.jax.org/app/browse/term/HP:0002539)__
#
# <hr>
#
# <p>
#   <b>Cortical Tubers</b>
#   <br />
# Cortical tubers in the brain are hamartomatous lesions typically located at the gray-white matter interface, commonly in the frontal and parietal lobes. Cortical tubers are composed of abnormal glial and neural cells, and the size, number, and location vary among patients.
# </p>
#
# __[Source 1](https://hpo.jax.org/app/browse/term/HP:0009717)__
#
# <hr>
#
# <p>
#   <b>Generalized abnormality of skin</b>
#   <br />
# An abnormality of the skin that is not localized to any one particular region.
#
#
# </p>
#
# __[Source 1](https://hpo.jax.org/app/browse/term/HP:0011354)__
#
# <hr>
#
# <p>
#   <b>Hypomelanotic macule</b>
#   <br />
# Hypomelanotic macules ("ash leaf spots") are white or lighter patches of skin that may appear anywhere on the body and are caused by a lack of melanin. White ash leaf-shaped macules are considered to be characteristic of tuberous sclerosis.
# </p>
#
# __[Source 1](https://hpo.jax.org/app/browse/term/HP:0009719)__
#
# <hr>
#
# <p>
#   <b>Subependymal nodules</b>
#   <br />
# Small nodular masses which originate in the subependymal region of the lateral ventricles and protrude into the ventricular cavity. They may represent subependymal hamartomas of tuberous sclerosis or nodular heterotopia of grey matter.
# </p>
#
# __[Source 1](https://hpo.jax.org/app/browse/term/HP:0009716)__

# %% [markdown]
# Brain findings:
# Benign brain tumor (astrocytoma)
# Abnormal organization of the brain (cortical dysplasia)
# Nodules in the brain (subependymal nodules)

# %%
Other systems:
Benign growth in the retina (retinal hamartoma)
Heart muscle tumor (cardiac rhabdomyoma)
Formation of unusual clumps of cells in the lungs (pulmonary lymphangiomyomatosis)
Kidney growths (renal angiomyolipoma)
Developmental delay
Intellectual disability
Behavioral issues

# %%
cortical tubers
subependymal nodules (SEN)
subependymal giant-cell astrocytomas (SEGA)

# %%
carcinogens

# %%
# Plants that Improve Memory and Concentration

memory_food = [
    'Ashwagandha', 'Bacopa Monnieri', 'Beans', 'Blueberries', 'Ginkgo Biloba',
    'Ginseng', 'Gotu Kola', 'Holy Basil', 'Huperzia', 'Kale', 'Peppermint',
    'Periwinkle', 'Reishi Mushroom', 'Rosemary', 'Sweet Flag Vacha', 'Thyme',
    'Yerba Mate'
]

# %%
fat_food = [
    
    'Avocados',
    'Flaxseeds',
    'Extra-Virgin Olive Oil (EVOO)',
    'Chia Seeds',
    'Walnuts',
    'Cacao Nibs',
    'Coconuts',
    'Coconut Oil',
    'Almonds',
    'Nut and seed butters',
    'Olives',
    'Tofu',
    'Edamame',
    'Anchovies',
    'Pumpkin seeds',
    'Macadamia nuts',
    'Edamame',
    'Edamame',
    'Edamame',
    'Edamame',
    'Sunflower seeds'
    
]
